# %%
# !pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/9.7 MB ? eta -:--:--
#    --- ------------------------------------ 0.8/9.7 MB 4.9 MB/s eta 0:00:02
#    -------- ------------------------------- 2.1/9.7 MB 5.2 MB/s eta 0:00:02
#    --------------- ------------------------ 3.7/9.7 MB 6.3 MB/s eta 0:00:01
#    ---------------------- ----------------- 5.5/9.7 MB 7.0 MB/s eta 0:00:01
#    --------------------------- ------------ 6.8/9.7 MB 6.8 MB/s eta 0:00:01
#    ---------------------------------- ----- 8.4/9.7 MB 7.0 MB/s eta 0:00:01
#    ---------------------------------------  9.7/9.7 MB 7.1 MB/s eta 0:00:01
#    ---------------------------------------- 9.7/9.7 MB 6.6 MB/s  0:00:01
# ...
#
#    ---------------------------------------- 0/2 [tzdata]
#    ---------------------------------------- 0/2 [tzdata]
#    ---------------------------------------- 0/2 [tzdata]
#    ---------------------------------------- 0/2 [tzdata]
#    ---------------------------------------- 0/2 [tzdata]
# ...

# %%
import pandas as pd
import numpy as np

# %%
#Id data - Series
data = [1,2,3,4,5]  
s = pd.Series(data)
print(s)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
#2d data - DataFrame
data = {'Name': ['Alice', 'Bob', 'Charlie'],    
        'Age': [25, 30, 35],    
        'City': ['New York', 'Los Angeles', 'Chicago']}             
df = pd.DataFrame(data)
print(df)
# Out:
#       Name  Age         City
# 0    Alice   25     New York
# 1      Bob   30  Los Angeles
# 2  Charlie   35      Chicago

# %%
df_csv = pd.read_csv('C:/DS2026/Python/Files/sales_data.csv')
df_csv.head()
# Out:
#    Transaction ID        Date Product Category             Product Name  \
# 0           10001  2024-01-01      Electronics            iPhone 14 Pro
# 1           10002  2024-01-02  Home Appliances         Dyson V11 Vacuum
# 2           10003  2024-01-03         Clothing         Levi's 501 Jeans
# 3           10004  2024-01-04            Books        The Da Vinci Code
# 4           10005  2024-01-05  Beauty Products  Neutrogena Skincare Set
#
#    Units Sold  Unit Price  Total Revenue         Region Payment Method
# 0           2      999.99        1999.98  North America    Credit Card
# 1           1      499.99         499.99         Europe         PayPal
# 2           3       69.99         209.97           Asia     Debit Card
# 3           4       15.99          63.96  North America    Credit Card
# 4           1       89.99          89.99         Europe         PayPal

# %%
# !pip install openpyxl
# Out:
# ...
#
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    ---------------------------------------- 2/2 [openpyxl]
#
# ...

# %%
import pandas as pd

df_excel = pd.read_excel('C:/DS2026/Python/Files/Sample-Data.xlsx', engine='openpyxl')
print(df_excel.head())
df_excel.head()
# Out:
#    Unnamed: 0               Unnamed: 1 Unnamed: 2   Unnamed: 3  Unnamed: 4  \
# 0         NaN        Excel Sample Data        NaN          NaN         NaN
# 1         NaN                      NaN        NaN          NaN         NaN
# 2         NaN  Project Management Data        NaN          NaN         NaN
# 3         NaN                      NaN        NaN          NaN         NaN
# 4         NaN             Project Name  Task Name  Assigned to  Start Date
#
#       Unnamed: 5 Unnamed: 6 Unnamed: 7
# 0            NaN        NaN        NaN
# 1            NaN        NaN        NaN
# 2            NaN        NaN        NaN
# 3            NaN        NaN        NaN
# 4  Days Required   End Date   Progress
#    Unnamed: 0               Unnamed: 1 Unnamed: 2   Unnamed: 3  Unnamed: 4  \
# 0         NaN        Excel Sample Data        NaN          NaN         NaN
# 1         NaN                      NaN        NaN          NaN         NaN
# ...

# %%
#Inspecting Data
print(df_csv.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 240 entries, 0 to 239
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction ID    240 non-null    int64
#  1   Date              240 non-null    str
#  2   Product Category  240 non-null    str
#  3   Product Name      240 non-null    str
#  4   Units Sold        240 non-null    int64
#  5   Unit Price        240 non-null    float64
#  6   Total Revenue     240 non-null    float64
#  7   Region            240 non-null    str
#  8   Payment Method    240 non-null    str
# dtypes: float64(2), int64(2), str(5)
# memory usage: 17.0 KB
# None

# %%
df_csv.describe()
# Out:
#        Transaction ID  Units Sold   Unit Price  Total Revenue
# count       240.00000  240.000000   240.000000     240.000000
# mean      10120.50000    2.158333   236.395583     335.699375
# std          69.42622    1.322454   429.446695     485.804469
# min       10001.00000    1.000000     6.500000       6.500000
# 25%       10060.75000    1.000000    29.500000      62.965000
# 50%       10120.50000    2.000000    89.990000     179.970000
# 75%       10180.25000    3.000000   249.990000     399.225000
# max       10240.00000   10.000000  3899.990000    3899.990000

# %%
df_csv.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 240 entries, 0 to 239
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction ID    240 non-null    int64
#  1   Date              240 non-null    str
#  2   Product Category  240 non-null    str
#  3   Product Name      240 non-null    str
#  4   Units Sold        240 non-null    int64
#  5   Unit Price        240 non-null    float64
#  6   Total Revenue     240 non-null    float64
#  7   Region            240 non-null    str
#  8   Payment Method    240 non-null    str
# dtypes: float64(2), int64(2), str(5)
# memory usage: 17.0 KB

# %%
df_csv.tail()
# Out:
#      Transaction ID        Date Product Category  \
# 235           10236  2024-08-23  Home Appliances
# 236           10237  2024-08-24         Clothing
# 237           10238  2024-08-25            Books
# 238           10239  2024-08-26  Beauty Products
# 239           10240  2024-08-27           Sports
#
#                                         Product Name  Units Sold  Unit Price  \
# 235  Nespresso Vertuo Next Coffee and Espresso Maker           1      159.99
# 236                        Nike Air Force 1 Sneakers           3       90.00
# 237           The Handmaid's Tale by Margaret Atwood           3       10.99
# 238             Sunday Riley Luna Sleeping Night Oil           1       55.00
# 239                       Yeti Rambler 20 oz Tumbler           2       29.99
#
#      Total Revenue         Region Payment Method
# 235         159.99         Europe         PayPal
# 236         270.00           Asia     Debit Card
# 237          32.97  North America    Credit Card
# ...

# %%
df_csv.shape
# Out:
# (240, 9)

# %%
df_csv.columns
# Out:
# Index(['Transaction ID', 'Date', 'Product Category', 'Product Name',
#        'Units Sold', 'Unit Price', 'Total Revenue', 'Region',
#        'Payment Method'],
#       dtype='str')

# %%
#Selecting a column
print(df_csv['Product Category'])
# Out:
# 0          Electronics
# 1      Home Appliances
# 2             Clothing
# 3                Books
# 4      Beauty Products
#             ...
# 235    Home Appliances
# 236           Clothing
# 237              Books
# 238    Beauty Products
# 239             Sports
# Name: Product Category, Length: 240, dtype: str

# %%
df_csv.head()
# Out:
#    Transaction ID        Date Product Category             Product Name  \
# 0           10001  2024-01-01      Electronics            iPhone 14 Pro
# 1           10002  2024-01-02  Home Appliances         Dyson V11 Vacuum
# 2           10003  2024-01-03         Clothing         Levi's 501 Jeans
# 3           10004  2024-01-04            Books        The Da Vinci Code
# 4           10005  2024-01-05  Beauty Products  Neutrogena Skincare Set
#
#    Units Sold  Unit Price  Total Revenue         Region Payment Method
# 0           2      999.99        1999.98  North America    Credit Card
# 1           1      499.99         499.99         Europe         PayPal
# 2           3       69.99         209.97           Asia     Debit Card
# 3           4       15.99          63.96  North America    Credit Card
# 4           1       89.99          89.99         Europe         PayPal

# %%
df_csv.iloc[1]
# Out:
# Transaction ID                 10002
# Date                      2024-01-02
# Product Category     Home Appliances
# Product Name        Dyson V11 Vacuum
# Units Sold                         1
# Unit Price                    499.99
# Total Revenue                 499.99
# Region                        Europe
# Payment Method                PayPal
# Name: 1, dtype: object

# %%
df_csv.loc[1]
# Out:
# Transaction ID                 10002
# Date                      2024-01-02
# Product Category     Home Appliances
# Product Name        Dyson V11 Vacuum
# Units Sold                         1
# Unit Price                    499.99
# Total Revenue                 499.99
# Region                        Europe
# Payment Method                PayPal
# Name: 1, dtype: object

# %%
df_csv.columns
# Out:
# Index(['Transaction ID', 'Date', 'Product Category', 'Product Name',
#        'Units Sold', 'Unit Price', 'Total Revenue', 'Region',
#        'Payment Method'],
#       dtype='str')

# %%
df_csv[df_csv['Units Sold']>2]
# Out:
#      Transaction ID        Date Product Category  \
# 2             10003  2024-01-03         Clothing
# 3             10004  2024-01-04            Books
# 5             10006  2024-01-06           Sports
# 8             10009  2024-01-09         Clothing
# 11            10012  2024-01-12           Sports
# ..              ...         ...              ...
# 225           10226  2024-08-13            Books
# 230           10231  2024-08-18         Clothing
# 233           10234  2024-08-21           Sports
# 236           10237  2024-08-24         Clothing
# 237           10238  2024-08-25            Books
#
#                                 Product Name  Units Sold  Unit Price  \
# 2                           Levi's 501 Jeans           3       69.99
# 3                          The Da Vinci Code           4       15.99
# 5                Wilson Evolution Basketball           5       29.99
# 8                           Nike Air Force 1           6       89.99
# ...

# %%
import pandas as pd

data = {
    "Name": ["Alice", "Bob", "Charlie"],
    "Age": [25, 30, 35]
}
df_data = pd.DataFrame(data, index=["A", "B", "C"])
print(df_data)
# Out:
#       Name  Age
# A    Alice   25
# B      Bob   30
# C  Charlie   35

# %%
#Modifying DataFrame
df_data.loc["B", "Age"] = 31

print(df_data)
# Out:
#       Name  Age
# A    Alice   25
# B      Bob   31
# C  Charlie   35

# %%
df_data['Salary'] = [50000, 60000, 45000]

df_data['Age'] = df_data['Age'] + 1

df_data
# Out:
#       Name  Age  Salary
# A    Alice   27   50000
# B      Bob   33   60000
# C  Charlie   37   45000

# %%
df_data['Department'] = ['HR', 'IT', 'Finance']
df_data
# Out:
#       Name  Age  Salary Department
# A    Alice   27   50000         HR
# B      Bob   33   60000         IT
# C  Charlie   37   45000    Finance

# %%
import pandas as pd

data = {
    "Name": ["Alice", "Bob", "Charlie"],
    "Age": [25, 30, 35],
    "Salary": [50000, 60000, 70000]
}
df1 = pd.DataFrame(data)
print("Original DataFrame:")
print(df1)

# Correct way: drop column
df1.drop('Salary', axis=1, inplace=True)
print("\nAfter dropping column 'Salary':")
print(df1)
# Out:
# Original DataFrame:
#       Name  Age  Salary
# 0    Alice   25   50000
# 1      Bob   30   60000
# 2  Charlie   35   70000
#
# After dropping column 'Salary':
#       Name  Age
# 0    Alice   25
# 1      Bob   30
# 2  Charlie   35

# %%
df.isnull()
df.isnull().sum()

df.dropna()           # remove missing
df.fillna(0)          # replace with 0
# Out:
#       Name  Age         City
# 0    Alice   25     New York
# 1      Bob   30  Los Angeles
# 2  Charlie   35      Chicago

# %%
df_csv.sort_values(by='Units Sold', ascending=True).head()
# Out:
#     Transaction ID        Date Product Category                 Product Name  \
# 1            10002  2024-01-02  Home Appliances             Dyson V11 Vacuum
# 4            10005  2024-01-05  Beauty Products      Neutrogena Skincare Set
# 6            10007  2024-01-07      Electronics          MacBook Pro 16-inch
# 10           10011  2024-01-11  Beauty Products         Chanel No. 5 Perfume
# 13           10014  2024-01-14  Home Appliances  Keurig K-Elite Coffee Maker
#
#     Units Sold  Unit Price  Total Revenue         Region Payment Method
# 1            1      499.99         499.99         Europe         PayPal
# 4            1       89.99          89.99         Europe         PayPal
# 6            1     2499.99        2499.99  North America    Credit Card
# 10           1      129.99         129.99         Europe         PayPal
# 13           1      189.99         189.99         Europe         PayPal

# %%
df_csv.groupby('Product Category')['Units Sold'].sum()
# Out:
# Product Category
# Beauty Products     46
# Books              114
# Clothing           145
# Electronics         66
# Home Appliances     59
# Sports              88
# Name: Units Sold, dtype: int64

# %%
df_csv.groupby('Payment Method')['Units Sold'].sum()
# Out:
# Payment Method
# Credit Card    268
# Debit Card     145
# PayPal         105
# Name: Units Sold, dtype: int64

# %%
df_csv.sort_values(by='Date', ascending=False).head()
# Out:
#      Transaction ID        Date Product Category  \
# 239           10240  2024-08-27           Sports
# 238           10239  2024-08-26  Beauty Products
# 237           10238  2024-08-25            Books
# 236           10237  2024-08-24         Clothing
# 235           10236  2024-08-23  Home Appliances
#
#                                         Product Name  Units Sold  Unit Price  \
# 239                       Yeti Rambler 20 oz Tumbler           2       29.99
# 238             Sunday Riley Luna Sleeping Night Oil           1       55.00
# 237           The Handmaid's Tale by Margaret Atwood           3       10.99
# 236                        Nike Air Force 1 Sneakers           3       90.00
# 235  Nespresso Vertuo Next Coffee and Espresso Maker           1      159.99
#
#      Total Revenue         Region Payment Method
# 239          59.98           Asia    Credit Card
# 238          55.00         Europe         PayPal
# 237          32.97  North America    Credit Card
# ...

# %%
#Dataframe merge and join

df1 = pd.DataFrame({'ID':[1,2], 'Name':['A','B']})
df2 = pd.DataFrame({'ID':[1,2], 'Salary':[50000,60000]})
pd.merge(df1, df2, on='ID')
# Out:
#    ID Name  Salary
# 0   1    A   50000
# 1   2    B   60000

# %%
df_csv[['Product Category','Units Sold']]
# Out:
#     Product Category  Units Sold
# 0        Electronics           2
# 1    Home Appliances           1
# 2           Clothing           3
# 3              Books           4
# 4    Beauty Products           1
# ..               ...         ...
# 235  Home Appliances           1
# 236         Clothing           3
# 237            Books           3
# 238  Beauty Products           1
# 239           Sports           2
#
# [240 rows x 2 columns]

# %%
df_csv.value_counts('Product Category')
# Out:
# Product Category
# Electronics        40
# Home Appliances    40
# Clothing           40
# Books              40
# Beauty Products    40
# Sports             40
# Name: count, dtype: int64

# %%
df_csv.drop_duplicates
# Out:
# <bound method DataFrame.drop_duplicates of      Transaction ID        Date Product Category  \
# 0             10001  2024-01-01      Electronics
# 1             10002  2024-01-02  Home Appliances
# 2             10003  2024-01-03         Clothing
# 3             10004  2024-01-04            Books
# 4             10005  2024-01-05  Beauty Products
# ..              ...         ...              ...
# 235           10236  2024-08-23  Home Appliances
# 236           10237  2024-08-24         Clothing
# 237           10238  2024-08-25            Books
# 238           10239  2024-08-26  Beauty Products
# 239           10240  2024-08-27           Sports
#
#                                         Product Name  Units Sold  Unit Price  \
# 0                                      iPhone 14 Pro           2      999.99
# 1                                   Dyson V11 Vacuum           1      499.99
# 2                                   Levi's 501 Jeans           3       69.99
# ...
