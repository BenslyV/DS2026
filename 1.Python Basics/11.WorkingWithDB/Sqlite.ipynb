# %%
import sqlite3

# %%
import sqlite3

# connect to database (creates file if not exists)
conn = sqlite3.connect("company.db")

# create cursor
cursor = conn.cursor()

# create table
cursor.execute("""
CREATE TABLE IF NOT EXISTS employees (
    id INTEGER PRIMARY KEY,
    name TEXT,
    salary REAL
)
""")

conn.commit()
conn.close()

# %%
#Insert data into the table
conn = sqlite3.connect("company.db")        
cursor = conn.cursor()
cursor.execute("INSERT INTO employees (name, salary) VALUES (?, ?)", ("Alice", 70000))
cursor.execute("INSERT INTO employees (name, salary) VALUES (?, ?)", ("Bob", 80000))
cursor.execute("INSERT INTO employees (name, salary) VALUES (?, ?)", ("John", 50000))

conn.commit()
conn.close()

# %%
conn = sqlite3.connect("company.db")        
cursor = conn.cursor()
cursor.execute("SELECT * FROM employees")
rows = cursor.fetchall()
for row in rows:
    print(row)  
conn.close()
# Out:
# (1, 'Alice', 70000.0)
# (2, 'Bob', 80000.0)
# (3, 'John', 50000.0)

# %%
#Update data

conn = sqlite3.connect("company.db")
cursor = conn.cursor()

cursor.execute("UPDATE employees SET salary = ? WHERE id = ?", (60000, 1))

conn.commit()
conn.close()

# %%
conn = sqlite3.connect("company.db")
cursor = conn.cursor()

cursor.execute("DELETE FROM employees WHERE id = ?", (1,))

conn.commit()
conn.close()

# %%
# %pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
#Using SQLite with Pandas (Important for Data Science)
import pandas as pd

conn = sqlite3.connect("company.db")

df = pd.read_sql_query("SELECT * FROM employees", conn)

print(df)
# Out:
#    id   name   salary
# 0   2    Bob  80000.0
# 1   3   John  50000.0
# 2   4  Alice  70000.0
# 3   5    Bob  80000.0
# 4   6   John  50000.0

# %%
conn = sqlite3.connect("company.db")
df1 = pd.read_sql_query("SELECT * FROM employees WHERE salary < 60000;", conn)
print(df1)
# Out:
#    id  name   salary
# 0   3  John  50000.0
# 1   6  John  50000.0

# %%
conn = sqlite3.connect("company.db")
df2 = pd.read_sql_query("SELECT * FROM employees ORDER BY salary DESC;", conn)
print(df2)
# Out:
#    id   name   salary
# 0   2    Bob  80000.0
# 1   5    Bob  80000.0
# 2   4  Alice  70000.0
# 3   3   John  50000.0
# 4   6   John  50000.0

# %%
conn = sqlite3.connect("company.db")
df2 = pd.read_sql_query("SELECT AVG(salary) FROM employees;", conn)
print(df2)
# Out:
#    AVG(salary)
# 0      66000.0

# %%
## Working Wwith Sales Data
# Connect to an SQLite database
connection = sqlite3.connect('sales_data.db')
cursor = connection.cursor()

# Create a table for sales data
cursor.execute('''
CREATE TABLE IF NOT EXISTS sales (
    id INTEGER PRIMARY KEY,
    date TEXT NOT NULL,
    product TEXT NOT NULL,
    sales INTEGER,
    region TEXT
)
''')

# Insert data into the sales table
sales_data = [
    ('2023-01-01', 'Product1', 100, 'North'),
    ('2023-01-02', 'Product2', 200, 'South'),
    ('2023-01-03', 'Product1', 150, 'East'),
    ('2023-01-04', 'Product3', 250, 'West'),
    ('2023-01-05', 'Product2', 300, 'North')
]

cursor.executemany('''
Insert into sales(date,product,sales,region)
                   values(?,?,?,?)
''',sales_data)

connection.commit()

# %%
# Query data from the sales table
cursor.execute('SELECT * FROM sales')
rows = cursor.fetchall()

# Print the queried data
for row in rows:
    print(row)
# Out:
# (1, '2023-01-01', 'Product1', 100, 'North')
# (2, '2023-01-02', 'Product2', 200, 'South')
# (3, '2023-01-03', 'Product1', 150, 'East')
# (4, '2023-01-04', 'Product3', 250, 'West')
# (5, '2023-01-05', 'Product2', 300, 'North')

# %%
## close the connection
connection.close()
