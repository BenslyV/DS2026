# %%
# Import NLTK and the tokenizer
import nltk
from nltk.tokenize import sent_tokenize

# %%
# Download the required tokenizer resources (run once)
nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\bensl\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\bensl\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
# (Optional) Add a custom NLTK data path if needed
# Uncomment only if NLTK cannot find the downloaded resources.
# nltk.data.path.append(r"C:\DS2026\Python\venv\nltk_data")

# Check the installed NLTK version
print("NLTK Version:", nltk.__version__)
# Out:
# NLTK Version: 3.9.4

# %%
# Sample text
text = (
    "Natural Language Processing is fun. "
    "NLTK makes it easy to tokenize text. "
    "Let's try sentence tokenization!"
)

# %%
sentences = sent_tokenize(text)

# Display the result
print(sentences)
# Out:
# ['Natural Language Processing is fun.', 'NLTK makes it easy to tokenize text.', "Let's try sentence tokenization!"]

# %%
#Example 2: Tokenizing a Custom Sentence
from nltk.tokenize import word_tokenize

text = "This movie is not good. The acting was terrible!"

words = word_tokenize(text)

print(words)
# Out:
# ['This', 'movie', 'is', 'not', 'good', '.', 'The', 'acting', 'was', 'terrible', '!']

# %%
#Filtering Stop Words 

import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
nltk.download('punkt')
nltk.download('punkt_tab')    # Required for newer NLTK versions
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\bensl\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\bensl\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\bensl\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# True

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# Sample text
text = "Natural Language Processing is one of the most exciting fields in Artificial Intelligence."

# %%
# Tokenize the text
words = word_tokenize(text)

# %%
print(words)
# Out:
# ['Natural', 'Language', 'Processing', 'is', 'one', 'of', 'the', 'most', 'exciting', 'fields', 'in', 'Artificial', 'Intelligence', '.']

# %%
stop_words = set(stopwords.words('english'))

# %%
filtered_words = [word for word in words if word.lower() not in stop_words]

# %%
# Display results
print("Original Words:")
print(words)

print("\nFiltered Words:")
print(filtered_words)
# Out:
# Original Words:
# ['Natural', 'Language', 'Processing', 'is', 'one', 'of', 'the', 'most', 'exciting', 'fields', 'in', 'Artificial', 'Intelligence', '.']
#
# Filtered Words:
# ['Natural', 'Language', 'Processing', 'one', 'exciting', 'fields', 'Artificial', 'Intelligence', '.']

# %%
# Python program for Stemming

from nltk.stem import PorterStemmer

from nltk.tokenize import word_tokenize

stemmer = PorterStemmer()
string_for_stemming = "The crew of the USS Discovery discovered many discoveries. Discovering is what explorers do."
words = word_tokenize(string_for_stemming)
print(words)
stemmed_words = [stemmer.stem(word) for word in words]
print(stemmed_words)
# Out:
# ['The', 'crew', 'of', 'the', 'USS', 'Discovery', 'discovered', 'many', 'discoveries', '.', 'Discovering', 'is', 'what', 'explorers', 'do', '.']
# ['the', 'crew', 'of', 'the', 'uss', 'discoveri', 'discov', 'mani', 'discoveri', '.', 'discov', 'is', 'what', 'explor', 'do', '.']

# %%
# Import NLTK libraries
import nltk
from nltk.tokenize import word_tokenize

# Download required resources (run only once)
nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('averaged_perceptron_tagger')
nltk.download('averaged_perceptron_tagger_eng')  # For newer NLTK versions

# Sample text
text = "The quick brown fox jumps over the lazy dog."

# Tokenize the sentence
words = word_tokenize(text)

# Perform POS tagging
pos_tags = nltk.pos_tag(words)

# Display the result
print("Part-of-Speech Tags:")
print(pos_tags)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\bensl\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\bensl\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\bensl\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     C:\Users\bensl\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger_eng.zip.
# Part-of-Speech Tags:
# [('The', 'DT'), ('quick', 'JJ'), ('brown', 'NN'), ('fox', 'NN'), ('jumps', 'VBZ'), ('over', 'IN'), ('the', 'DT'), ('lazy', 'JJ'), ('dog', 'NN'), ('.', '.')]

# %%
#Python Program for Lemmatization 
 
import nltk 
nltk.download('punkt') 
nltk.download('wordnet') 
from nltk.stem import WordNetLemmatizer 
from nltk.tokenize import word_tokenize 
lemmatizer = WordNetLemmatizer() 
string_for_lemmatizing = "The friends of DeSoto love scarves." 
words = word_tokenize(string_for_lemmatizing) 
lemmatized_words = [lemmatizer.lemmatize(word) for word in words] 
print(lemmatized_words)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\bensl\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\bensl\AppData\Roaming\nltk_data...
# ['The', 'friend', 'of', 'DeSoto', 'love', 'scarf', '.']

# %%
#Python Program using NLTK

# Import libraries
import nltk
from nltk.tokenize import word_tokenize
from nltk import pos_tag, ne_chunk

# Download required resources (run only once)
nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('averaged_perceptron_tagger')
nltk.download('averaged_perceptron_tagger_eng')
nltk.download('maxent_ne_chunker')
nltk.download('maxent_ne_chunker_tab')
nltk.download('words')

# Sample sentence
text = "Sundar Pichai is the CEO of Google and lives in California."

# Tokenize
words = word_tokenize(text)

# POS Tagging
tagged_words = pos_tag(words)

# Named Entity Recognition
entities = ne_chunk(tagged_words)

# Display the result
print(entities)
